# %%
import pandas as pd
import numpy as np
import math

# remove corrupted data

df = pd.read_csv('train.csv')
# del df['MOFname']
df.replace(0, np.nan, inplace=True)
df.replace(-1, np.nan, inplace=True)
df.replace(math.inf, np.nan, inplace=True)
df.dropna(axis=0, how='any', inplace=True)
df.to_csv('train_rm.csv')
df
# Out:
#               MOFname  volume [A^3]   weight [u]  surface_area [m^2/g]  \
# 1          mof_unit_2   2769.503842  2211.697211                603.61
# 2          mof_unit_3   1089.818728   773.687960                788.50
# 3          mof_unit_4   2205.198301  1304.638720               1441.53
# 5          mof_unit_6   3954.659761  1543.027680               2430.55
# 6          mof_unit_7   3565.914939  1954.749656               1530.02
# ...               ...           ...          ...                   ...
# 66519  mof_unit_66520   1426.479810  1272.451540               1343.62
# 66520  mof_unit_66521  23943.701366  5497.752320               4182.24
# 66521  mof_unit_66522  14389.971556  4396.164320               4149.64
# 66522  mof_unit_66523  16997.806645  3932.703680               4326.62
# 66523  mof_unit_66524   7391.212513  2142.468600               3835.28
#
#        void_fraction  void_volume [cm^3/g] functional_groups  metal_linker  \
# ...

# %%
mean = df.mean(axis=0)
median = df.median(axis=0)

# %%
# mean (exclude nan at functional_groups and topology)
# TODO word embedding at functional_groups and topology to improve this method

df = pd.read_csv('train.csv')
df.dropna(subset=['functional_groups', 'topology'], inplace=True)
df.replace(0, np.nan, inplace=True)
df.replace(-1, np.nan, inplace=True)
df.replace(math.inf, np.nan, inplace=True)
df.fillna(mean, inplace=True)
df.to_csv('train_mean.csv')
df
# Out:
#               MOFname  volume [A^3]   weight [u]  surface_area [m^2/g]  \
# 0          mof_unit_1   1116.667429   875.240600            2110.48672
# 1          mof_unit_2   2769.503842  2211.697211             603.61000
# 2          mof_unit_3   1089.818728   773.687960             788.50000
# 3          mof_unit_4   2205.198301  1304.638720            1441.53000
# 4          mof_unit_5   1137.800963   901.736120            2110.48672
# ...               ...           ...          ...                   ...
# 68608  mof_unit_68609   1188.302573  1001.700216            2110.48672
# 68609  mof_unit_68610   1506.660363  1493.296496            2110.48672
# 68610  mof_unit_68611   2035.532738  1959.518320            2110.48672
# 68611  mof_unit_68612   3985.426053  3638.677280            2110.48672
# 68612  mof_unit_68613   1591.009408  2071.219000            2110.48672
#
#        void_fraction  void_volume [cm^3/g] functional_groups  metal_linker  \
# ...

# %%
# median (exclude nan at functional_groups and topology)
# TODO word embedding at functional_groups and topology to improve this method

df = pd.read_csv('train.csv')
df.dropna(subset=['functional_groups', 'topology'], inplace=True)
df.replace(0, np.nan, inplace=True)
df.replace(-1, np.nan, inplace=True)
df.replace(math.inf, np.nan, inplace=True)
df.fillna(median, inplace=True)
df.to_csv('train_median.csv')
df
# Out:
#               MOFname  volume [A^3]   weight [u]  surface_area [m^2/g]  \
# 0          mof_unit_1   1116.667429   875.240600              1916.215
# 1          mof_unit_2   2769.503842  2211.697211               603.610
# 2          mof_unit_3   1089.818728   773.687960               788.500
# 3          mof_unit_4   2205.198301  1304.638720              1441.530
# 4          mof_unit_5   1137.800963   901.736120              1916.215
# ...               ...           ...          ...                   ...
# 68608  mof_unit_68609   1188.302573  1001.700216              1916.215
# 68609  mof_unit_68610   1506.660363  1493.296496              1916.215
# 68610  mof_unit_68611   2035.532738  1959.518320              1916.215
# 68611  mof_unit_68612   3985.426053  3638.677280              1916.215
# 68612  mof_unit_68613   1591.009408  2071.219000              1916.215
#
#        void_fraction  void_volume [cm^3/g] functional_groups  metal_linker  \
# ...

# %%
# TODO regression, inference-based tools using a Bayesian formalism, or decision tree induction
